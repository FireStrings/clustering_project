# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("data/pokemon_data.csv")
df.head()
# 
ax = sns.distplot(df["Sp. Atk"])
ax.figure.set_size_inches(12,6)
ax.set_title("Distribuição de Frequecias - Ataque", fontsize=18)
ax.set_xlabel("Ataque", fontsize=14)
ax
# df.query("50 < Attack < 60").count()
# df.Attack.hist(bins=50, figsize=(12,6))

# X = df["Sp. Def"].values
# Y = df["Defense"].values

# # df
# # for i in range(0, 50):
# #     print(X[i], Y[i])
# print(np.corrcoef(X,Y))
# plt.scatter(X,Y)
# # plt.plot(X, regressor.predict(X), color="red")
# plt.title("Regressão simples")
# plt.xlabel("Idade")
# plt.ylabel("Custo")
# df.groupby("Generation").mean().sort_values(by="Legendary", ascending=False)
# df[df["Generation"] == 4]
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.6/dist-packages/matplotlib/cbook/__init__.py:1402: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   ndim = x[:, None].ndim
# /usr/local/lib/python3.6/dist-packages/matplotlib/axes/_base.py:276: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x = x[:, np.newaxis]
# ...

# %%
ax = sns.distplot(df.Attack, hist_kws={"cumulative":True}, kde_kws={"cumulative":True})
ax.figure.set_size_inches(14,6)
ax.set_title("Distribuição de Frequecia Acumulada ", fontsize=18)
ax.set_ylabel("Acumulado", fontsize=14)
ax.set_xlabel("Anos", fontsize=14)
ax
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.6/dist-packages/matplotlib/cbook/__init__.py:1402: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   ndim = x[:, None].ndim
# /usr/local/lib/python3.6/dist-packages/matplotlib/axes/_base.py:276: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x = x[:, np.newaxis]
# ...

# %%
# df.loc[df["Legendary"] == True]

# %%
df["Mean"] = (df["HP"] + df["Attack"] + df["Defense"] + df["Sp. Atk"] + df["Sp. Def"] + df["Speed"])/6

# %%
df.loc[df["Mean"] == df["Mean"].max()]
# Out:
#        #                   Name   Type 1    Type 2   HP  Attack  Defense  \
# 163  150    MewtwoMega Mewtwo X  Psychic  Fighting  106     190      100
# 164  150    MewtwoMega Mewtwo Y  Psychic       NaN  106     150       70
# 426  384  RayquazaMega Rayquaza   Dragon    Flying  105     180      100
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary   Mean
# 163      154      100    130           1       True  130.0
# 164      194      120    140           1       True  130.0
# 426      180      100    115           3       True  130.0

# %%
import matplotlib.pyplot as plt
# df.plot(kind='bar',x='Type 1',y='Attack')
# ax = plt.gca()
# df.plot(kind='line',x='Type 1',y='Speed',ax=ax)
# df.plot(kind='line',x='name',y='num_pets', color='red', ax=ax)

# %%
df.groupby(["Generation"]).mean()
# Out:
#                      #         HP     Attack    Defense    Sp. Atk    Sp. Def  \
# Generation
# 1            75.819277  65.819277  76.638554  70.861446  71.819277  69.090361
# 2           202.283019  71.207547  72.028302  73.386792  65.943396  73.905660
# 3           321.968750  66.543750  81.625000  74.100000  75.806250  71.225000
# 4           442.446281  73.082645  82.867769  78.132231  76.404959  77.190083
# 5           574.272727  71.787879  82.066667  72.327273  71.987879  68.739394
# 6           688.012195  68.268293  75.804878  76.682927  74.292683  74.890244
#
#                 Speed  Legendary       Mean
# Generation
# 1           72.584337   0.036145  71.135542
# 2           61.811321   0.047170  69.713836
# 3           66.925000   0.112500  72.704167
# 4           71.338843   0.107438  76.502755
# 5           68.078788   0.090909  72.497980
# 6           66.439024   0.097561  72.729675

# %%
# df["HP"].value_counts(normalize=True)*100
# pd.crosstab(df["Type 2"], df["Legendary"], aggfunc='mean', values=df.Attack)
# df.head()
classes = [5, 20, 40, 90, 140, 190]
labels = ['E','D','C','B','A']
pd.value_counts(pd.cut(x=df.Attack, bins=classes, labels=labels, include_lowest=True), normalize=True)*100
# df.Attack.max()
# Out:
# C    57.875
# B    27.250
# D     8.875
# A     4.250
# E     1.750
# Name: Attack, dtype: float64

# %%
df.Attack.quantile([.25, .5, .75])

# %%
df = pd.read_csv("data/pokemon_data.csv")

# %%
df.corr()
# Out:
#                    #        HP    Attack   Defense   Sp. Atk   Sp. Def  \
# #           1.000000  0.097614  0.102298  0.094786  0.088759  0.085817
# HP          0.097614  1.000000  0.422386  0.239622  0.362380  0.378718
# Attack      0.102298  0.422386  1.000000  0.438687  0.396362  0.263990
# Defense     0.094786  0.239622  0.438687  1.000000  0.223549  0.510747
# Sp. Atk     0.088759  0.362380  0.396362  0.223549  1.000000  0.506121
# Sp. Def     0.085817  0.378718  0.263990  0.510747  0.506121  1.000000
# Speed       0.010733  0.175952  0.381240  0.015227  0.473018  0.259133
# Generation  0.982516  0.058683  0.051451  0.042419  0.036437  0.028486
# Legendary   0.153396  0.273620  0.345408  0.246377  0.448907  0.363937
#
#                Speed  Generation  Legendary
# #           0.010733    0.982516   0.153396
# HP          0.175952    0.058683   0.273620
# Attack      0.381240    0.051451   0.345408
# Defense     0.015227    0.042419   0.246377
# ...

# %%
df.plot(kind="scatter", x="#", y="Generation")

# %%
df.describe()
# Out:
#                 #          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  800.000000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750   69.258750   79.001250   73.842500   72.820000   71.902500
# std    208.343798   25.534669   32.457366   31.183501   32.722294   27.828916
# min      1.000000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    184.750000   50.000000   55.000000   50.000000   49.750000   50.000000
# 50%    364.500000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    539.250000   80.000000  100.000000   90.000000   95.000000   90.000000
# max    721.000000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             Speed  Generation
# count  800.000000   800.00000
# mean    68.277500     3.32375
# std     29.060474     1.66129
# min      5.000000     1.00000
# 25%     45.000000     2.00000
# 50%     65.000000     3.00000
# 75%     90.000000     5.00000
# ...

# %%
df.plot(kind="scatter", x="Attack", y="Defense", alpha=0.4,
            s=df["population"]/100, label="population", figsize=(10,7), 
            c="median_house_value", cmap=plt.get_cmap("jet"), colorbar=True)
